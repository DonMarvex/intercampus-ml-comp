# %%
import pandas as pd
import numpy as np
# Load normalized dataset from Azure Machine Learning
data = pd.read_csv('C:\\Users\\USER\\Documents\\INTER CAMPUS MACHINE LEARNING 2018\\NORMALISED\\trainnormalized.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4990 entries, 0 to 4989
# Data columns (total 13 columns):
# Product_Identifier                4990 non-null object
# Supermarket_Identifier            4990 non-null object
# Product_Supermarket_Identifier    4990 non-null object
# Product_Weight                    4990 non-null float64
# Product_Fat_Content               4990 non-null object
# Product_Shelf_Visibility          4990 non-null float64
# Product_Type                      4990 non-null object
# Product_Price                     4990 non-null float64
# Supermarket_Opening_Year          4990 non-null float64
# Supermarket _Size                 4990 non-null object
# Supermarket_Location_Type         4990 non-null object
# Supermarket_Type                  4990 non-null object
# Product_Supermarket_Sales         4990 non-null float64
# dtypes: float64(5), object(8)
# memory usage: 506.9+ KB

# %%
data
# Out:
#      Product_Identifier Supermarket_Identifier Product_Supermarket_Identifier  \
# 0                 DRA12            CHUKWUDI010              DRA12_CHUKWUDI010
# 1                 DRA12            CHUKWUDI013              DRA12_CHUKWUDI013
# 2                 DRA12            CHUKWUDI017              DRA12_CHUKWUDI017
# 3                 DRA12            CHUKWUDI018              DRA12_CHUKWUDI018
# 4                 DRA12            CHUKWUDI035              DRA12_CHUKWUDI035
# 5                 DRA12            CHUKWUDI045              DRA12_CHUKWUDI045
# 6                 DRA24            CHUKWUDI010              DRA24_CHUKWUDI010
# 7                 DRA24            CHUKWUDI013              DRA24_CHUKWUDI013
# 8                 DRA24            CHUKWUDI017              DRA24_CHUKWUDI017
# 9                 DRA24            CHUKWUDI019              DRA24_CHUKWUDI019
# 10                DRA24            CHUKWUDI027              DRA24_CHUKWUDI027
# 11                DRA24            CHUKWUDI035              DRA24_CHUKWUDI035
# 12                DRA24            CHUKWUDI049              DRA24_CHUKWUDI049
# 13                DRA59            CHUKWUDI017              DRA59_CHUKWUDI017
# 14                DRA59            CHUKWUDI018              DRA59_CHUKWUDI018
# 15                DRA59            CHUKWUDI019              DRA59_CHUKWUDI019
# 16                DRA59            CHUKWUDI027              DRA59_CHUKWUDI027
# 17                DRA59            CHUKWUDI046              DRA59_CHUKWUDI046
# 18                DRA59            CHUKWUDI049              DRA59_CHUKWUDI049
# 19                DRB01            CHUKWUDI027              DRB01_CHUKWUDI027
# 20                DRB01            CHUKWUDI049              DRB01_CHUKWUDI049
# 21                DRB13            CHUKWUDI017              DRB13_CHUKWUDI017
# 22                DRB13            CHUKWUDI035              DRB13_CHUKWUDI035
# 23                DRB13            CHUKWUDI049              DRB13_CHUKWUDI049
# 24                DRB24            CHUKWUDI017              DRB24_CHUKWUDI017
# 25                DRB24            CHUKWUDI035              DRB24_CHUKWUDI035
# 26                DRB24            CHUKWUDI045              DRB24_CHUKWUDI045
# 27                DRB24            CHUKWUDI049              DRB24_CHUKWUDI049
# 28                DRB25            CHUKWUDI010              DRB25_CHUKWUDI010
# 29                DRB25            CHUKWUDI013              DRB25_CHUKWUDI013
# ...                 ...                    ...                            ...
# 4960              NCZ06            CHUKWUDI019              NCZ06_CHUKWUDI019
# ...                  ...            ...                       ...
# 4960           Household       0.950636                  0.000000
# 4961           Household       0.944689                  0.000000
# 4962  Health and Hygiene       0.026169                  0.541667
# 4963           Household       0.942990                  0.916667
# 4964           Household       0.940016                  0.000000
# 4965           Household       0.941290                  0.791667
# 4966           Household       0.951911                  0.708333
# 4967  Health and Hygiene       0.402913                  0.541667
# 4968  Health and Hygiene       0.400364                  0.083333
# 4969  Health and Hygiene       0.398240                  0.500000
# 4970           Household       0.381978                  0.541667
# 4971           Household       0.382402                  0.083333
# 4972           Household       0.372207                  0.916667
# 4973           Household       0.371782                  0.583333
# 4974  Health and Hygiene       0.402216                  0.083333
# 4975  Health and Hygiene       0.392020                  0.916667
# 4976  Health and Hygiene       0.402216                  1.000000
# 4977  Health and Hygiene       0.404765                  0.791667
# 4978           Household       0.871009                  0.916667
# 4979           Household       0.868035                  0.791667
# 4980  Health and Hygiene       0.659009                  1.000000
# 4981  Health and Hygiene       0.675152                  0.000000
# 4982  Health and Hygiene       0.670054                  0.583333
# 4983           Household       0.552533                  0.541667
# 4984           Household       0.560604                  1.000000
# 4985           Household       0.549984                  0.000000
# 4986           Household       0.563153                  0.000000
# 4987           Household       0.556356                  0.708333
# 4988           Household       0.554232                  0.500000
# 4989           Household       0.551683                  0.583333
#
#      Supermarket _Size Supermarket_Location_Type   Supermarket_Type  \
# 0               Medium                 Cluster 3      Grocery Store
# 1                 High                 Cluster 3  Supermarket Type1
# 2                Small                 Cluster 2  Supermarket Type1
# 3               Medium                 Cluster 3  Supermarket Type2
# 4                Small                 Cluster 2  Supermarket Type1
# 5                Small                 Cluster 2  Supermarket Type1
# 6               Medium                 Cluster 3      Grocery Store
# 7                 High                 Cluster 3  Supermarket Type1
# 8                Small                 Cluster 2  Supermarket Type1
# 9                Small                 Cluster 1      Grocery Store
# 10              Medium                 Cluster 3  Supermarket Type3
# 11               Small                 Cluster 2  Supermarket Type1
# 12              Medium                 Cluster 1  Supermarket Type1
# 13               Small                 Cluster 2  Supermarket Type1
# 14              Medium                 Cluster 3  Supermarket Type2
# 15               Small                 Cluster 1      Grocery Store
# 16              Medium                 Cluster 3  Supermarket Type3
# 17               Small                 Cluster 1  Supermarket Type1
# 18              Medium                 Cluster 1  Supermarket Type1
# 19              Medium                 Cluster 3  Supermarket Type3
# 20              Medium                 Cluster 1  Supermarket Type1
# 21               Small                 Cluster 2  Supermarket Type1
# 22               Small                 Cluster 2  Supermarket Type1
# 23              Medium                 Cluster 1  Supermarket Type1
# 24               Small                 Cluster 2  Supermarket Type1
# 25               Small                 Cluster 2  Supermarket Type1
# 26               Small                 Cluster 2  Supermarket Type1
# 27              Medium                 Cluster 1  Supermarket Type1
# 28              Medium                 Cluster 3      Grocery Store
# 29                High                 Cluster 3  Supermarket Type1
# ...                ...                       ...                ...
# 4960             Small                 Cluster 1      Grocery Store
# 4961            Medium                 Cluster 3  Supermarket Type3
# 4962            Medium                 Cluster 3      Grocery Store
# 4963             Small                 Cluster 2  Supermarket Type1
# 4964             Small                 Cluster 1      Grocery Store
# 4965             Small                 Cluster 2  Supermarket Type1
# 4966             Small                 Cluster 2  Supermarket Type1
# 4967            Medium                 Cluster 3      Grocery Store
# 4968              High                 Cluster 3  Supermarket Type1
# 4969             Small                 Cluster 1  Supermarket Type1
# 4970            Medium                 Cluster 3      Grocery Store
# 4971              High                 Cluster 3  Supermarket Type1
# 4972             Small                 Cluster 2  Supermarket Type1
# 4973            Medium                 Cluster 1  Supermarket Type1
# 4974              High                 Cluster 3  Supermarket Type1
# 4975             Small                 Cluster 2  Supermarket Type1
# 4976            Medium                 Cluster 3  Supermarket Type2
# 4977             Small                 Cluster 2  Supermarket Type1
# 4978             Small                 Cluster 2  Supermarket Type1
# 4979             Small                 Cluster 2  Supermarket Type1
# 4980            Medium                 Cluster 3  Supermarket Type2
# 4981            Medium                 Cluster 3  Supermarket Type3
# 4982            Medium                 Cluster 1  Supermarket Type1
# 4983            Medium                 Cluster 3      Grocery Store
# 4984            Medium                 Cluster 3  Supermarket Type2
# 4985             Small                 Cluster 1      Grocery Store
# 4986            Medium                 Cluster 3  Supermarket Type3
# 4987             Small                 Cluster 2  Supermarket Type1
# 4988             Small                 Cluster 1  Supermarket Type1
# 4989            Medium                 Cluster 1  Supermarket Type1
#
#       Product_Supermarket_Sales
# 0                        709.08
# 1                       6381.69
# 2                       6381.69
# 3                       2127.23
# 4                       2481.77
# 5                       9572.54
# 6                        818.93
# 7                      11055.61
# 8                       2866.27
# 9                       1228.40
# 10                     12284.01
# 11                      8598.81
# 12                      2456.80
# 13                      6015.50
# 14                     11105.54
# 15                      1388.19
# 16                     17583.78
# 17                     11105.54
# 18                      3239.12
# 19                      1423.15
# 20                      3795.06
# 21                      8538.89
# 22                      1423.15
# 23                      9013.27
# 24                      4633.97
# 25                      5406.30
# 26                     10426.43
# 27                     10040.26
# 28                       535.97
# 29                      5091.71
# ...                         ...
# 4960                    1902.52
# 4961                    8244.27
# 4962                      94.88
# 4963                   17122.71
# 4964                    1902.52
# 4965                   15220.19
# 4966                    3805.05
# 4967                    1258.36
# 4968                    7550.17
# 4969                    3460.50
# 4970                     602.55
# 4971                    1506.37
# 4972                    2410.20
# 4973                    6326.76
# 4974                    2190.48
# 4975                    6258.52
# 4976                    4693.89
# 4977                    4380.96
# 4978                   10073.55
# 4979                   10666.12
# 4980                    4710.54
# 4981                   14131.61
# 4982                    9892.12
# 4983                     812.28
# 4984                    6498.21
# 4985                     406.14
# 4986                   13808.69
# 4987                    5685.93
# 4988                   11778.00
# 4989                   17870.07
#
# [4990 rows x 13 columns]

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
# Display column headers
data.columns
# Out:
# Index(['Product_Identifier', 'Supermarket_Identifier',
#        'Product_Supermarket_Identifier', 'Product_Weight',
#        'Product_Fat_Content', 'Product_Shelf_Visibility', 'Product_Type',
#        'Product_Price', 'Supermarket_Opening_Year', 'Supermarket _Size',
#        'Supermarket_Location_Type', 'Supermarket_Type',
#        'Product_Supermarket_Sales'],
#       dtype='object')

# %%
features = []
for i in data.columns:
    features.append(i)
    
print(features)
# Out:
# ['Product_Identifier', 'Supermarket_Identifier', 'Product_Supermarket_Identifier', 'Product_Weight', 'Product_Fat_Content', 'Product_Shelf_Visibility', 'Product_Type', 'Product_Price', 'Supermarket_Opening_Year', 'Supermarket _Size', 'Supermarket_Location_Type', 'Supermarket_Type', 'Product_Supermarket_Sales']

# %%
predictors = ['Product_Identifier', 'Supermarket_Identifier', 'Product_Fat_Content', 'Product_Shelf_Visibility', 'Product_Type', 'Product_Price', 'Supermarket_Opening_Year', 'Supermarket _Size', 'Supermarket_Location_Type', 'Supermarket_Type', 'Product_Supermarket_Sales']

# %%
X = data[predictors]
# Display the predictors
X
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4990 entries, 0 to 4989
# Data columns (total 11 columns):
# Product_Identifier           4990 non-null object
# Supermarket_Identifier       4990 non-null object
# Product_Fat_Content          4990 non-null object
# Product_Shelf_Visibility     4990 non-null float64
# Product_Type                 4990 non-null object
# Product_Price                4990 non-null float64
# Supermarket_Opening_Year     4990 non-null float64
# Supermarket _Size            4990 non-null object
# Supermarket_Location_Type    4990 non-null object
# Supermarket_Type             4990 non-null object
# Product_Supermarket_Sales    4990 non-null float64
# dtypes: float64(4), object(7)
# memory usage: 428.9+ KB

# %%
# Identify categorical features
cat = ['Product_Identifier', 'Supermarket_Identifier', 'Product_Fat_Content', 'Product_Type', 'Supermarket _Size', 'Supermarket_Location_Type', 'Supermarket_Type']
Xcat = X[cat]
# Convert categorical features to numerical using LabelEncoder
Xcat = Xcat.apply(LabelEncoder().fit_transform)

# %%
# Identify numerical features
num = ['Product_Shelf_Visibility', 'Product_Price', 'Supermarket_Opening_Year']
Xnum = X[num]
# Create new
Xnew = pd.concat([Xcat,Xnum],axis=1)

# %%
# Identnify varibale to be predicted
y = X['Product_Supermarket_Sales']
# Display X
X
X.info()
Xnew
Xnew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4990 entries, 0 to 4989
# Data columns (total 11 columns):
# Product_Identifier           4990 non-null object
# Supermarket_Identifier       4990 non-null object
# Product_Fat_Content          4990 non-null object
# Product_Shelf_Visibility     4990 non-null float64
# Product_Type                 4990 non-null object
# Product_Price                4990 non-null float64
# Supermarket_Opening_Year     4990 non-null float64
# Supermarket _Size            4990 non-null object
# Supermarket_Location_Type    4990 non-null object
# Supermarket_Type             4990 non-null object
# Product_Supermarket_Sales    4990 non-null float64
# dtypes: float64(4), object(7)
# memory usage: 428.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4990 entries, 0 to 4989
# Data columns (total 10 columns):
# Product_Identifier           4990 non-null int64
# Supermarket_Identifier       4990 non-null int64
# Product_Fat_Content          4990 non-null int64
# Product_Type                 4990 non-null int64
# Supermarket _Size            4990 non-null int64
# Supermarket_Location_Type    4990 non-null int64
# Supermarket_Type             4990 non-null int64
# Product_Shelf_Visibility     4990 non-null float64
# Product_Price                4990 non-null float64
# Supermarket_Opening_Year     4990 non-null float64
# dtypes: float64(3), int64(7)
# memory usage: 389.9 KB

# %%
test = pd.read_csv('C:\\Users\\USER\\Documents\\INTER CAMPUS MACHINE LEARNING 2018\\NORMALISED\\testnormalized.csv')
test
# Out:
#      Product_Identifier Supermarket_Identifier Product_Supermarket_Identifier  \
# 0                 DRA59            CHUKWUDI010              DRA59_CHUKWUDI010
# 1                 DRA59            CHUKWUDI013              DRA59_CHUKWUDI013
# 2                 DRB01            CHUKWUDI013              DRB01_CHUKWUDI013
# 3                 DRB13            CHUKWUDI010              DRB13_CHUKWUDI010
# 4                 DRB13            CHUKWUDI013              DRB13_CHUKWUDI013
# 5                 DRB25            CHUKWUDI017              DRB25_CHUKWUDI017
# 6                 DRB25            CHUKWUDI027              DRB25_CHUKWUDI027
# 7                 DRB25            CHUKWUDI035              DRB25_CHUKWUDI035
# 8                 DRB48            CHUKWUDI017              DRB48_CHUKWUDI017
# 9                 DRB48            CHUKWUDI027              DRB48_CHUKWUDI027
# 10                DRB48            CHUKWUDI035              DRB48_CHUKWUDI035
# 11                DRB48            CHUKWUDI046              DRB48_CHUKWUDI046
# 12                DRB48            CHUKWUDI049              DRB48_CHUKWUDI049
# 13                DRC01            CHUKWUDI017              DRC01_CHUKWUDI017
# 14                DRC01            CHUKWUDI018              DRC01_CHUKWUDI018
# 15                DRC01            CHUKWUDI027              DRC01_CHUKWUDI027
# 16                DRC01            CHUKWUDI045              DRC01_CHUKWUDI045
# 17                DRC01            CHUKWUDI046              DRC01_CHUKWUDI046
# 18                DRC13            CHUKWUDI035              DRC13_CHUKWUDI035
# 19                DRC13            CHUKWUDI045              DRC13_CHUKWUDI045
# 20                DRC25            CHUKWUDI018              DRC25_CHUKWUDI018
# 21                DRC25            CHUKWUDI019              DRC25_CHUKWUDI019
# 22                DRC25            CHUKWUDI027              DRC25_CHUKWUDI027
# 23                DRC25            CHUKWUDI045              DRC25_CHUKWUDI045
# 24                DRC25            CHUKWUDI046              DRC25_CHUKWUDI046
# 25                DRC27            CHUKWUDI010              DRC27_CHUKWUDI010
# 26                DRC27            CHUKWUDI018              DRC27_CHUKWUDI018
# 27                DRC27            CHUKWUDI049              DRC27_CHUKWUDI049
# 28                DRC36            CHUKWUDI013              DRC36_CHUKWUDI013
# 29                DRD01            CHUKWUDI017              DRD01_CHUKWUDI017
# ...                 ...                    ...                            ...
# 3502              NCY41            CHUKWUDI035              NCY41_CHUKWUDI035
# 3503              NCY41            CHUKWUDI045              NCY41_CHUKWUDI045
# 3504              NCY41            CHUKWUDI046              NCY41_CHUKWUDI046
# 3505              NCY41            CHUKWUDI049              NCY41_CHUKWUDI049
# 3506              NCY53            CHUKWUDI017              NCY53_CHUKWUDI017
# 3507              NCY53            CHUKWUDI027              NCY53_CHUKWUDI027
# 3508              NCZ05            CHUKWUDI019              NCZ05_CHUKWUDI019
# 3509              NCZ05            CHUKWUDI035              NCZ05_CHUKWUDI035
# 3510              NCZ06            CHUKWUDI013              NCZ06_CHUKWUDI013
# 3511              NCZ06            CHUKWUDI018              NCZ06_CHUKWUDI018
# 3512              NCZ06            CHUKWUDI046              NCZ06_CHUKWUDI046
# 3513              NCZ06            CHUKWUDI049              NCZ06_CHUKWUDI049
# 3514              NCZ17            CHUKWUDI017              NCZ17_CHUKWUDI017
# 3515              NCZ17            CHUKWUDI018              NCZ17_CHUKWUDI018
# 3518  Health and Hygiene       0.031240                  0.500000
# 3519           Household       0.943463                  1.000000
# 3520           Household       0.951527                  0.500000
# 3521           Household       0.946858                  0.583333
# 3522  Health and Hygiene       0.409362                  0.708333
# 3523           Household       0.384625                  0.000000
# 3524           Household       0.379531                  0.791667
# 3525           Household       0.383351                  0.708333
# 3526  Health and Hygiene       0.398903                  0.708333
# 3527           Household       0.878759                  0.541667
# 3528           Household       0.873241                  0.083333
# 3529           Household       0.866874                  0.583333
# 3530  Health and Hygiene       0.668212                  0.541667
# 3531  Health and Hygiene       0.659298                  0.083333
#
#      Supermarket _Size Supermarket_Location_Type   Supermarket_Type
# 0               Medium                 Cluster 3      Grocery Store
# 1                 High                 Cluster 3  Supermarket Type1
# 2                 High                 Cluster 3  Supermarket Type1
# 3               Medium                 Cluster 3      Grocery Store
# 4                 High                 Cluster 3  Supermarket Type1
# 5                Small                 Cluster 2  Supermarket Type1
# 6               Medium                 Cluster 3  Supermarket Type3
# 7                Small                 Cluster 2  Supermarket Type1
# 8                Small                 Cluster 2  Supermarket Type1
# 9               Medium                 Cluster 3  Supermarket Type3
# 10               Small                 Cluster 2  Supermarket Type1
# 11               Small                 Cluster 1  Supermarket Type1
# 12              Medium                 Cluster 1  Supermarket Type1
# 13               Small                 Cluster 2  Supermarket Type1
# 14              Medium                 Cluster 3  Supermarket Type2
# 15              Medium                 Cluster 3  Supermarket Type3
# 16               Small                 Cluster 2  Supermarket Type1
# 17               Small                 Cluster 1  Supermarket Type1
# 18               Small                 Cluster 2  Supermarket Type1
# 19               Small                 Cluster 2  Supermarket Type1
# 20              Medium                 Cluster 3  Supermarket Type2
# 21               Small                 Cluster 1      Grocery Store
# 22              Medium                 Cluster 3  Supermarket Type3
# 23               Small                 Cluster 2  Supermarket Type1
# 24               Small                 Cluster 1  Supermarket Type1
# 25              Medium                 Cluster 3      Grocery Store
# 26              Medium                 Cluster 3  Supermarket Type2
# 27              Medium                 Cluster 1  Supermarket Type1
# 28                High                 Cluster 3  Supermarket Type1
# 29               Small                 Cluster 2  Supermarket Type1
# ...                ...                       ...                ...
# 3502             Small                 Cluster 2  Supermarket Type1
# 3503             Small                 Cluster 2  Supermarket Type1
# 3504             Small                 Cluster 1  Supermarket Type1
# 3505            Medium                 Cluster 1  Supermarket Type1
# 3506             Small                 Cluster 2  Supermarket Type1
# 3507            Medium                 Cluster 3  Supermarket Type3
# 3508             Small                 Cluster 1      Grocery Store
# 3509             Small                 Cluster 2  Supermarket Type1
# 3510              High                 Cluster 3  Supermarket Type1
# 3511            Medium                 Cluster 3  Supermarket Type2
# 3512             Small                 Cluster 1  Supermarket Type1
# 3513            Medium                 Cluster 1  Supermarket Type1
# 3514             Small                 Cluster 2  Supermarket Type1
# 3515            Medium                 Cluster 3  Supermarket Type2
# 3516            Medium                 Cluster 3  Supermarket Type3
# 3517             Small                 Cluster 2  Supermarket Type1
# 3518             Small                 Cluster 1  Supermarket Type1
# 3519            Medium                 Cluster 3  Supermarket Type2
# 3520             Small                 Cluster 1  Supermarket Type1
# 3521            Medium                 Cluster 1  Supermarket Type1
# 3522             Small                 Cluster 2  Supermarket Type1
# 3523            Medium                 Cluster 3  Supermarket Type3
# 3524             Small                 Cluster 2  Supermarket Type1
# 3525             Small                 Cluster 2  Supermarket Type1
# 3526             Small                 Cluster 2  Supermarket Type1
# 3527            Medium                 Cluster 3      Grocery Store
# 3528              High                 Cluster 3  Supermarket Type1
# 3529            Medium                 Cluster 1  Supermarket Type1
# 3530            Medium                 Cluster 3      Grocery Store
# 3531              High                 Cluster 3  Supermarket Type1
#
# [3532 rows x 12 columns]

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3532 entries, 0 to 3531
# Data columns (total 12 columns):
# Product_Identifier                3532 non-null object
# Supermarket_Identifier            3532 non-null object
# Product_Supermarket_Identifier    3532 non-null object
# Product_Weight                    3532 non-null float64
# Product_Fat_Content               3532 non-null object
# Product_Shelf_Visibility          3532 non-null float64
# Product_Type                      3532 non-null object
# Product_Price                     3532 non-null float64
# Supermarket_Opening_Year          3532 non-null float64
# Supermarket _Size                 3532 non-null object
# Supermarket_Location_Type         3532 non-null object
# Supermarket_Type                  3532 non-null object
# dtypes: float64(4), object(8)
# memory usage: 331.2+ KB

# %%
test.columns
# Out:
# Index(['Product_Identifier', 'Supermarket_Identifier',
#        'Product_Supermarket_Identifier', 'Product_Weight',
#        'Product_Fat_Content', 'Product_Shelf_Visibility', 'Product_Type',
#        'Product_Price', 'Supermarket_Opening_Year', 'Supermarket _Size',
#        'Supermarket_Location_Type', 'Supermarket_Type'],
#       dtype='object')

# %%
testpredictors = ['Product_Identifier', 'Supermarket_Identifier', 'Product_Fat_Content', 'Product_Shelf_Visibility', 'Product_Type', 'Product_Price', 'Supermarket_Opening_Year', 'Supermarket _Size', 'Supermarket_Location_Type', 'Supermarket_Type']
X1 = test[testpredictors]
X1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3532 entries, 0 to 3531
# Data columns (total 10 columns):
# Product_Identifier           3532 non-null object
# Supermarket_Identifier       3532 non-null object
# Product_Fat_Content          3532 non-null object
# Product_Shelf_Visibility     3532 non-null float64
# Product_Type                 3532 non-null object
# Product_Price                3532 non-null float64
# Supermarket_Opening_Year     3532 non-null float64
# Supermarket _Size            3532 non-null object
# Supermarket_Location_Type    3532 non-null object
# Supermarket_Type             3532 non-null object
# dtypes: float64(3), object(7)
# memory usage: 276.0+ KB

# %%
# Convert categorical features to numerical features
testcat = ['Product_Identifier', 'Supermarket_Identifier', 'Product_Fat_Content', 'Product_Type', 'Supermarket _Size', 'Supermarket_Location_Type', 'Supermarket_Type']
Xtestcat = X1[testcat]
# Convert categorical features to numerical using LabelEncoder
Xtestcat = Xtestcat.apply(LabelEncoder().fit_transform)

# Identify numerical features
testnum = ['Product_Shelf_Visibility', 'Product_Price', 'Supermarket_Opening_Year']
Xtestnum = X1[testnum]
# Create new
Xtestnew = pd.concat([Xtestcat,Xtestnum],axis=1)
Xtestnew
# Out:
#       Product_Identifier  Supermarket_Identifier  Product_Fat_Content  \
# 0                      0                       0                    1
# 1                      0                       1                    1
# 2                      1                       1                    0
# 3                      2                       0                    1
# 4                      2                       1                    1
# 5                      3                       2                    0
# 6                      3                       5                    0
# 7                      3                       6                    0
# 8                      4                       2                    1
# 9                      4                       5                    1
# 10                     4                       6                    1
# 11                     4                       8                    1
# 12                     4                       9                    1
# 13                     5                       2                    1
# 14                     5                       3                    1
# 15                     5                       5                    1
# 16                     5                       7                    1
# 17                     5                       8                    1
# 18                     6                       6                    1
# 19                     6                       7                    1
# 20                     7                       3                    0
# 21                     7                       4                    0
# 22                     7                       5                    0
# 23                     7                       7                    0
# 24                     7                       8                    0
# 25                     8                       0                    0
# 26                     8                       3                    0
# 27                     8                       9                    0
# 28                     9                       1                    1
# 29                    10                       2                    1
# ...                  ...                     ...                  ...
# 3502                1196                       6                    0
# 3503                1196                       7                    2
# 3504                1196                       8                    0
# 3505                1196                       9                    0
# 3506                1197                       2                    0
# 3507                1197                       5                    0
# 3508                1198                       4                    0
# 3509                1198                       6                    0
# 3510                1199                       1                    0
# 3511                1199                       3                    0
# 3512                1199                       8                    0
# 3513                1199                       9                    0
# 3514                1200                       2                    2
# 3515                1200                       3                    0
# 3516                1200                       5                    0
# 3517                1200                       7                    0
# 3518                1200                       8                    0
# 3519                1201                       3                    0
# 3520                1201                       8                    0
# 3521                1201                       9                    0
# 3522                1202                       7                    0
# 3523                1203                       5                    2
# 3524                1203                       6                    0
# 3525                1203                       7                    0
# 3526                1204                       7                    0
# 3527                1205                       0                    0
# 3528                1205                       1                    0
# 3529                1205                       9                    2
# 3530                1206                       0                    0
# 3531                1206                       1                    0
#
#       Product_Type  Supermarket _Size  Supermarket_Location_Type  \
# 0               14                  1                          2
# 1               14                  0                          2
# 2               14                  0                          2
# 3               14                  1                          2
# 4               14                  0                          2
# 5               14                  2                          1
# 6               14                  1                          2
# 7               14                  2                          1
# 8               14                  2                          1
# 9               14                  1                          2
# 10              14                  2                          1
# 11              14                  2                          0
# 12              14                  1                          0
# 13              14                  2                          1
# 14              14                  1                          2
# 15              14                  1                          2
# 16              14                  2                          1
# 17              14                  2                          0
# 18              14                  2                          1
# 19              14                  2                          1
# 20              14                  1                          2
# 21              14                  2                          0
# 22              14                  1                          2
# 23              14                  2                          1
# 24              14                  2                          0
# 25               4                  1                          2
# 26               4                  1                          2
# 27               4                  1                          0
# 28              14                  0                          2
# 29              14                  2                          1
# ...            ...                ...                        ...
# 3502             8                  2                          1
# 3503             8                  2                          1
# 3504             8                  2                          0
# 3505             8                  1                          0
# 3506             8                  2                          1
# 3507             8                  1                          2
# 3508             8                  2                          0
# 3509             8                  2                          1
# 3510             9                  0                          2
# 3511             9                  1                          2
# 3512             9                  2                          0
# 3513             9                  1                          0
# 3514             8                  2                          1
# 3515             8                  1                          2
# 3516             8                  1                          2
# 3517             8                  2                          1
# 3518             8                  2                          0
# 3519             9                  1                          2
# 3520             9                  2                          0
# 3521             9                  1                          0
# 3522             8                  2                          1
# 3523             9                  1                          2
# 3524             9                  2                          1
# 3525             9                  2                          1
# 3526             8                  2                          1
# 3527             9                  1                          2
# 3528             9                  0                          2
# 3503                  0.708333
# 3504                  0.500000
# 3505                  0.583333
# 3506                  0.916667
# 3507                  0.000000
# 3508                  0.000000
# 3509                  0.791667
# 3510                  0.083333
# 3511                  1.000000
# 3512                  0.500000
# 3513                  0.583333
# 3514                  0.916667
# 3515                  1.000000
# 3516                  0.000000
# 3517                  0.708333
# 3518                  0.500000
# 3519                  1.000000
# 3520                  0.500000
# 3521                  0.583333
# 3522                  0.708333
# 3523                  0.000000
# 3524                  0.791667
# 3525                  0.708333
# 3526                  0.708333
# 3527                  0.541667
# 3528                  0.083333
# 3529                  0.583333
# 3530                  0.541667
# 3531                  0.083333
#
# [3532 rows x 10 columns]

# %%
from sklearn.feature_selection import RFE
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
# Use a train test split
X_train, X_test, Y_train, Y_test = train_test_split (Xnew, y, test_size = 0.20, random_state=42)

# Checking different models
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
pipelines = []
pipelines.append(('ScaledLR', Pipeline([('Scaler', StandardScaler()),('LR',LinearRegression())])))
pipelines.append(('ScaledLASSO', Pipeline([('Scaler', StandardScaler()),('LASSO', Lasso())])))
pipelines.append(('ScaledEN', Pipeline([('Scaler', StandardScaler()),('EN', ElasticNet())])))
pipelines.append(('ScaledKNN', Pipeline([('Scaler', StandardScaler()),('KNN', KNeighborsRegressor())])))
pipelines.append(('ScaledCART', Pipeline([('Scaler', StandardScaler()),('CART', DecisionTreeRegressor())])))
pipelines.append(('ScaledGBM', Pipeline([('Scaler', StandardScaler()),('GBM', GradientBoostingRegressor())])))
pipelines.append(('ScaledRF', Pipeline([('Scaler', StandardScaler()),('RF', RandomForestRegressor())])))

results = []
names = []
for name, model in pipelines:
    kfold = KFold(n_splits=10, random_state=21)
    cv_results = cross_val_score(model, X_train, Y_train, cv=kfold, scoring='neg_mean_squared_error')
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# ScaledLR: -10256862.441651 (775460.690391)
# ScaledLASSO: -10256151.677225 (775745.134959)
# ScaledEN: -10912035.230517 (1058544.311047)
# ScaledKNN: -10457113.875265 (717803.127636)
# ScaledCART: -17797297.948186 (1340812.466553)
# ScaledGBM: -8771551.964417 (526401.714013)
# ScaledRF: -10616485.445400 (713325.863359)

# %%
from sklearn.model_selection import GridSearchCV

scaler = StandardScaler().fit(X_train)
rescaledX = scaler.transform(X_train)
param_grid = dict(n_estimators=np.array([50,100,200,300,400]))
model = RandomForestRegressor(random_state=21)
kfold = KFold(n_splits=10, random_state=21)
grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring='neg_mean_squared_error', cv=kfold)
grid_result = grid.fit(rescaledX, Y_train)

means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))

print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# -9613822.525953 (557710.213901) with: {'n_estimators': 50}
# -9530120.850361 (555347.824653) with: {'n_estimators': 100}
# -9488534.103784 (544304.147836) with: {'n_estimators': 200}
# -9465541.170647 (530891.880569) with: {'n_estimators': 300}
# -9459372.082541 (539588.572688) with: {'n_estimators': 400}
# Best: -9459372.082541 using {'n_estimators': 400}

# %%
from sklearn.linear_model import LinearRegression 
lm = LinearRegression()
lm.fit(Xnew,y)
predictions1 = lm.predict(Xnew)
print(predictions1)
# from sklearn import metrics
# np.sqrt(metrics.mean_squared_error(y, predictions1))
# Out:
# [2147.89573278 4789.25829908 4682.38054487 ... 6380.7267737  6233.05877629
#  6341.05096166]

# %%
from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators=400, random_state=21)  
regressor.fit(Xnew, y)  
predictions2 = regressor.predict(Xtestnew)
# from sklearn import metrics
# np.sqrt(metrics.mean_squared_error(y, predictions2))

# %%
predic = pd.DataFrame(predictions2)
predic
# results can be any variable name eg dataExport, predict, etc
dataExport = pd.concat([Xtestnew,predic],axis=1)
dataExport.to_csv('C:\\Users\\USER\\Documents\\INTER CAMPUS MACHINE LEARNING 2018\\NORMALISED\\Submission12.csv', index=False)

# %%
from sklearn.ensemble import GradientBoostingRegressor

regressor2 = GradientBoostingRegressor(n_estimators=400, random_state=21)  
regressor2.fit(Xnew, y)  
predictions3 = regressor2.predict(Xtestnew)
#from sklearn import metrics
#np.sqrt(metrics.mean_squared_error(y, predictions3))
predic = pd.DataFrame(predictions3)
predic
# Out:
#                  0
# 0      1392.654592
# 1      9973.970970
# 2      8116.107959
# 3       831.361520
# 4      8014.875885
# 5      2257.710564
# 6      4380.365445
# 7      2347.695655
# 8      3008.410466
# 9      7276.439662
# 10     3079.598433
# 11     2793.464153
# 12     3368.601436
# 13     3275.585679
# 14     2278.665491
# 15     7765.685157
# 16     3476.517268
# 17     3137.451630
# 18     5458.324530
# 19     5292.867223
# 20     3384.490634
# 21      701.441927
# 22     8485.940297
# 23     4000.549536
# 24     3802.901283
# 25     1440.747364
# 26     7892.660912
# 27     8162.886948
# 28     7027.203717
# 29     3234.225167
# ...            ...
# 3502   2463.461603
# 3503   2422.566473
# 3504   2246.693454
# 3505   2425.215967
# 3506   4629.361099
# 3507   7251.144911
# 3508    684.616529
# 3509   4382.678895
# 3510   8515.736516
# 3511   7903.876044
# 3512   8355.923593
# 3513   9241.920170
# 3514   2921.129476
# 3515   1774.486888
# 3516   5298.250027
# 3517   2277.867630
# 3518   2340.400669
# 3519   7359.139691
# 3520  10294.663460
# 3521   9201.278062
# 3522   4792.493497
# 3523   7638.427284
# 3524   5355.086008
# 3525   4868.806785
# 3526   4986.926294
# 3527   2664.211851
# 3528   9611.978886
# 3529   9239.168930
# 3530   1873.568438
# 3531   7688.830307
#
# [3532 rows x 1 columns]

# %%
from sklearn.ensemble import GradientBoostingRegressor

regressor2 = GradientBoostingRegressor(n_estimators=6000, random_state=21)  
regressor2.fit(Xnew, y)  
predictions3 = regressor2.predict(Xtestnew)
#from sklearn import metrics
#np.sqrt(metrics.mean_squared_error(y, predictions3))
predic = pd.DataFrame(predictions3)
predic
# Out:
#                  0
# 0       777.058867
# 1     10780.449022
# 2      9291.275907
# 3     -1681.232660
# 4      7785.019362
# 5      1237.545015
# 6      2488.886392
# 7      1597.667657
# 8      5510.660336
# 9      7322.128812
# 10     2076.023696
# 11     3675.334719
# 12     4614.068571
# 13     3040.830144
# 14     2558.488120
# 15     7318.954136
# 16     3224.004656
# 17     3421.112264
# 18     6732.179698
# 19     6341.242010
# 20     4804.742275
# 21    -1331.485309
# 22    11896.655557
# 23     3531.671616
# 24     3090.391670
# 25     2973.551096
# 26    10868.387337
# 27     4325.136240
# 28     5442.602000
# 29     3790.041314
# ...            ...
# 3502   1168.753477
# 3503   1204.765218
# 3504   1242.529749
# 3505   1082.695471
# 3506   5596.364496
# 3507   7057.176412
# 3508   2063.498197
# 3509   3896.645930
# 3510    416.655222
# 3511   6518.836751
# 3512   4669.882493
# 3513   4661.871750
# 3514   3400.001969
# 3515    382.013293
# 3516   5686.757359
# 3517   1840.292373
# 3518    851.616673
# 3519   5616.230262
# 3520   8999.276578
# 3521   7573.385241
# 3522   3650.313787
# 3523   7553.316970
# 3524   6267.763433
# 3525   7284.386654
# 3526   5005.046095
# 3527   2243.883154
# 3528   9259.268806
# 3529   8427.617548
# 3530   1813.343849
# 3531   6134.237193
#
# [3532 rows x 1 columns]

# %%
from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators=100, random_state=21)  
regressor.fit(Xnew, y)  
predictions2 = regressor.predict(Xtestnew)
#from sklearn import metrics
#np.sqrt(metrics.mean_squared_error(y, predictions2))
predic = pd.DataFrame(predictions2)
predic
# Out:
#                0
# 0      1115.0810
# 1      9973.2831
# 2      8531.5617
# 3      1315.9371
# 4      8873.7668
# 5      4321.3754
# 6      7968.9612
# 7      4141.7424
# 8      1781.3132
# 9      6995.5447
# 10     1718.8277
# 11     1974.4127
# 12     1781.3132
# 13     1744.8798
# 14     1749.2908
# 15     6799.9337
# 16     1743.7646
# 17     1779.8011
# 18     4431.1663
# 19     6315.2637
# 20     4246.5217
# 21      385.2648
# 22     9627.7190
# 23     4228.2290
# 24     4292.3291
# 25     1506.0563
# 26     7453.7291
# 27     6846.7025
# 28     8476.1334
# 29     2088.1648
# ...          ...
# 3502   1430.3390
# 3503   1491.7257
# 3504   1430.3390
# 3505   1571.6220
# 3506   3288.4862
# 3507   7591.5193
# 3508    693.6478
# 3509   3570.5529
# 3510   8863.3633
# 3511   6817.4109
# 3512   8595.8948
# 3513   8872.3850
# 3514   1562.0164
# 3515   1594.4258
# 3516   7257.7038
# 3517   1573.8860
# 3518   1664.5016
# 3519   7421.8067
# 3520   6912.3042
# 3521   8144.9164
# 3522   5401.4697
# 3523   8502.6495
# 3524   5919.2451
# 3525   6740.4435
# 3526   5031.8173
# 3527   1119.7450
# 3528  10611.5713
# 3529   8047.1595
# 3530   1237.7393
# 3531   7311.8835
#
# [3532 rows x 1 columns]

# %%
from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators=200, random_state=21)  
regressor.fit(Xnew, y)  
predictions2 = regressor.predict(Xtestnew)
#from sklearn import metrics
#np.sqrt(metrics.mean_squared_error(y, predictions2))
predic = pd.DataFrame(predictions2)
predic
# Out:
#                 0
# 0      1095.31520
# 1      9749.64080
# 2      8471.34025
# 3      1375.75080
# 4      8153.55450
# 5      4288.41000
# 6      7809.94340
# 7      4117.37385
# 8      1789.83555
# 9      6530.63315
# 10     1738.24415
# 11     2039.85245
# 12     1785.24150
# 13     1764.87055
# 14     1777.76215
# 15     6451.16285
# 16     1759.40265
# 17     1793.97435
# 18     4590.04295
# 19     6216.01785
# 20     4242.76005
# 21      400.52020
# 22     9658.62880
# 23     4230.90885
# 24     4202.57930
# 25     1561.31745
# 26     7528.87280
# 27     6838.05535
# 28     8689.54720
# 29     2015.50115
# ...           ...
# 3502   1361.23730
# 3503   1465.76750
# 3504   1362.92675
# 3505   1564.68925
# 3506   3382.56375
# 3507   7211.34725
# 3508    614.59260
# 3509   3705.26895
# 3510   9469.49965
# 3511   6828.13865
# 3512   9251.65805
# 3513   9493.21030
# 3514   1636.48590
# 3515   1605.36975
# 3516   6539.16410
# 3517   1569.14205
# 3518   1642.18870
# 3519   7236.36470
# 3520   7127.40740
# 3521   8177.34055
# 3522   5236.82565
# 3523   8270.38545
# 3524   5893.56180
# 3525   6525.68105
# 3526   4726.16520
# 3527   1102.48375
# 3528  11022.09510
# 3529   8106.71520
# 3530   1292.72610
# 3531   7536.31640
#
# [3532 rows x 1 columns]

# %%
from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators=1000, random_state=21)  
regressor.fit(Xnew, y)  
predictions2 = regressor.predict(Xtestnew)
#from sklearn import metrics
#np.sqrt(metrics.mean_squared_error(y, predictions2))
predic = pd.DataFrame(predictions2)
predic
dataExport = pd.concat([Xtestnew,predic],axis=1)
dataExport.to_csv('C:\\Users\\USER\\Documents\\INTER CAMPUS MACHINE LEARNING 2018\\NORMALISED\\Submission13.csv', index=False)
